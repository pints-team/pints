# %% [markdown]
# # PMC ABC
#
# attempt 2

# %%
import pints
import pints.toy as toy
import pints.plot
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(3)
# Load a forward model
model = toy.StochasticDegradationModel()
# Create some toy data
real_parameters = model.suggested_parameters()
times = np.linspace(0, 10, 100)
for i in range(10):
    values = model.simulate(real_parameters, times)
    # Create an object with links to the model and time series
    problem = pints.SingleOutputProblem(model, times, values)
    # Create a uniform prior parameter
    log_prior = pints.UniformLogPrior([0.0], [0.3])
    # Set the error measure to be used to compare simulated to observed data
    error_measure = pints.RootMeanSquaredError(problem)
    plt.step(times, values)

plt.xlabel('time')
plt.ylabel('concentration (A(t))')
plt.show()

# %%
abc = pints.ABCController(error_measure, log_prior, method=pints.ABCPMC)

# set threshold
abc.sampler().set_threshold(1)

# set target number of samples
abc.set_n_samples(10)

# Referenced memory pula mea si explodeaza
# cred ca null memory

abc.set_parallel(True)

# log to screen
abc.set_log_to_screen(True)

print('Running...')
samples  = abc.run()
print('Done')
# Out:
# Running...
# Using Rejection ABC
# Running in parallel with 8 worker processess.
# initializing weights to 0.125
# sending [[0.1861538]] for vibe check
# sending [[0.13629354]] for vibe check
# sending [[0.0471734]] for vibe check
# sending [[0.18523626]] for vibe check
# sending [[0.04592679]] for vibe check
# sending [[0.00927876]] for vibe check
# sending [[0.14385219]] for vibe check
# sending [[0.08239124]] for vibe check
# w_sum ** 2 = 1.0 whereas w_sq_sum = 0.125
# received cov 0.011887816230602737 with n=8
# first branch
# sending [array([0.05295916])] for vibe check
# received cov 0.011887816230602737 with n=8
# first branch
# sending [array([0.13297445])] for vibe check
# received cov 0.011887816230602737 with n=8
# first branch
# sending [array([0.03985058])] for vibe check
# received cov 0.011887816230602737 with n=8
# first branch
# sending [array([0.04446645])] for vibe check
# received cov 0.011887816230602737 with n=8
# first branch
# sending [array([0.18092746])] for vibe check
# received cov 0.011887816230602737 with n=8
# first branch
# sending [array([0.00349046])] for vibe check
# received cov 0.011887816230602737 with n=8
# first branch
# sending [array([0.04565459])] for vibe check
# received cov 0.011887816230602737 with n=8
# first branch
# sending [array([0.18910398])] for vibe check
# w_sum ** 2 = 1.0 whereas w_sq_sum = 0.14354295082010765
# received cov 0.005728281099358522 with n=8
# first branch
# sending [array([0.17822455])] for vibe check
# received cov 0.005728281099358522 with n=8
# first branch
# sending [array([0.18158608])] for vibe check
# received cov 0.005728281099358522 with n=8
# first branch
# sending [array([0.13113232])] for vibe check
# received cov 0.005728281099358522 with n=8
# first branch
# sending [array([0.00435617])] for vibe check
# received cov 0.005728281099358522 with n=8
# first branch
# sending [array([0.19899054])] for vibe check
# received cov 0.005728281099358522 with n=8
# first branch
# sending [array([0.18016597])] for vibe check
# received cov 0.005728281099358522 with n=8
# first branch
# sending [array([0.00571446])] for vibe check
# received cov 0.005728281099358522 with n=8
# D:\Part B\python\lib\site-packages\pints\_abc\_abc_pmc.py:167: RuntimeWarning: divide by zero encountered in double_scalars
#   self._n_weights[self._i] = (self._log_prior(self._n_theta[self._i]) / norm_term)
# first branch
# sending [array([0.00127288])] for vibe check
# w_sum ** 2 = 1.0 whereas w_sq_sum = 0.14603509894405392
# received cov 0.00674518109358829 with n=8
# first branch
# sending [array([0.21199905])] for vibe check
# received cov 0.00674518109358829 with n=8
# first branch
# sending [array([0.19488973])] for vibe check
# received cov 0.00674518109358829 with n=8
# first branch
# sending [array([0.18557281])] for vibe check
# received cov 0.00674518109358829 with n=8
# first branch
# sending [array([0.17838591])] for vibe check
# received cov 0.00674518109358829 with n=8
# first branch
# sending [array([0.17975182])] for vibe check
# received cov 0.00674518109358829 with n=8
# first branch
# sending [array([0.20378761])] for vibe check
# received cov 0.00674518109358829 with n=8
# first branch
# sending [array([0.13000116])] for vibe check
# received cov 0.00674518109358829 with n=8
# first branch
# sending [array([0.14275204])] for vibe check
# w_sum ** 2 = 1.0 whereas w_sq_sum = 0.1452283142008265
# received cov 0.0005416996611077092 with n=8
# first branch
# sending [array([0.18573])] for vibe check
# received cov 0.0005416996611077092 with n=8
# first branch
# sending [array([0.14312522])] for vibe check
# received cov 0.0005416996611077092 with n=8
# first branch
# sending [array([0.19641293])] for vibe check
# received cov 0.0005416996611077092 with n=8
# first branch
# sending [array([0.14288854])] for vibe check
# received cov 0.0005416996611077092 with n=8
# first branch
# sending [array([0.19431126])] for vibe check
# received cov 0.0005416996611077092 with n=8
# first branch
# sending [array([0.17980422])] for vibe check
# received cov 0.0005416996611077092 with n=8
# first branch
# sending [array([0.17896402])] for vibe check
# received cov 0.0005416996611077092 with n=8
# first branch
# sending [array([0.18009928])] for vibe check
# w_sum ** 2 = 1.0 whereas w_sq_sum = 0.18690800135241117
# received cov 0.0006341098628137213 with n=8
# first branch
# sending [array([0.14406419])] for vibe check
# received cov 0.0006341098628137213 with n=8
# first branch
# sending [array([0.14372595])] for vibe check
# received cov 0.0006341098628137213 with n=8
# first branch
# sending [array([0.18089455])] for vibe check
# received cov 0.0006341098628137213 with n=8
# first branch
# sending [array([0.19491693])] for vibe check
# received cov 0.0006341098628137213 with n=8
# first branch
# sending [array([0.19646755])] for vibe check
# received cov 0.0006341098628137213 with n=8
# first branch
# sending [array([0.14217246])] for vibe check
# received cov 0.0006341098628137213 with n=8
# first branch
# sending [array([0.14273805])] for vibe check
# received cov 0.0006341098628137213 with n=8
# first branch
# sending [array([0.14344995])] for vibe check
# w_sum ** 2 = 1.0 whereas w_sq_sum = 0.1720812506575928
# received cov 0.0005653830047474693 with n=8
# first branch
# sending [array([0.14228085])] for vibe check
# received cov 0.0005653830047474693 with n=8
# first branch
# sending [array([0.14366908])] for vibe check
# received cov 0.0005653830047474693 with n=8
# first branch
# sending [array([0.19706992])] for vibe check
# received cov 0.0005653830047474693 with n=8
# first branch
# sending [array([0.14357096])] for vibe check
# received cov 0.0005653830047474693 with n=8
# first branch
# sending [array([0.1423817])] for vibe check
# received cov 0.0005653830047474693 with n=8
# first branch
# sending [array([0.19742128])] for vibe check
# received cov 0.0005653830047474693 with n=8
# first branch
# sending [array([0.14221471])] for vibe check
# received cov 0.0005653830047474693 with n=8
# first branch
# sending [array([0.14370899])] for vibe check
# w_sum ** 2 = 1.0 whereas w_sq_sum = 0.17592177599725675
# received cov 0.0006648237212497302 with n=8
# first branch
# sending [array([0.14357938])] for vibe check
# received cov 0.0006648237212497302 with n=8
# first branch
# sending [array([0.19690991])] for vibe check
# received cov 0.0006648237212497302 with n=8
# first branch
# sending [array([0.14343249])] for vibe check
# received cov 0.0006648237212497302 with n=8
# first branch
# sending [array([0.14356101])] for vibe check
# received cov 0.0006648237212497302 with n=8
# first branch
# sending [array([0.14149429])] for vibe check
# received cov 0.0006648237212497302 with n=8
# first branch
# sending [array([0.1976343])] for vibe check
# received cov 0.0006648237212497302 with n=8
# first branch
# sending [array([0.14316202])] for vibe check
# received cov 0.0006648237212497302 with n=8
# first branch
# sending [array([0.14157471])] for vibe check
# w_sum ** 2 = 1.0000000000000004 whereas w_sq_sum = 0.17817260159732087
# received cov 0.0008702311021392627 with n=8
# first branch
# sending [array([0.14270846])] for vibe check
# received cov 0.0008702311021392627 with n=8
# first branch
# sending [array([0.19805746])] for vibe check
# received cov 0.0008702311021392627 with n=8
# first branch
# sending [array([0.19673821])] for vibe check
# received cov 0.0008702311021392627 with n=8
# first branch
# sending [array([0.14067819])] for vibe check
# received cov 0.0008702311021392627 with n=8
# first branch
# sending [array([0.14328157])] for vibe check
# received cov 0.0008702311021392627 with n=8
# first branch
# sending [array([0.14411505])] for vibe check
# received cov 0.0008702311021392627 with n=8
# first branch
# sending [array([0.14092232])] for vibe check
# received cov 0.0008702311021392627 with n=8
# first branch
# sending [array([0.14498866])] for vibe check
# w_sum ** 2 = 0.9999999999999998 whereas w_sq_sum = 0.19293342636624833
# received cov 0.0009341479854499795 with n=8
# first branch
# sending [array([0.19652558])] for vibe check
# received cov 0.0009341479854499795 with n=8
# first branch
# sending [array([0.14346672])] for vibe check
# received cov 0.0009341479854499795 with n=8
# first branch
# sending [array([0.1406513])] for vibe check
# received cov 0.0009341479854499795 with n=8
# first branch
# sending [array([0.13930131])] for vibe check
# received cov 0.0009341479854499795 with n=8
# first branch
# sending [array([0.14017972])] for vibe check
# received cov 0.0009341479854499795 with n=8
# first branch
# sending [array([0.14649931])] for vibe check
# received cov 0.0009341479854499795 with n=8
# first branch
# sending [array([0.19682325])] for vibe check
# received cov 0.0009341479854499795 with n=8
# first branch
# sending [array([0.19879117])] for vibe check
# Iter. Eval. Acceptance rate Time m:s
# 1     640    0.0140625        0:02.9
# received cov 0.0009341479854499795 with n=8
# first branch
# sending [array([0.13871643])] for vibe check
# 2     648    0.0277777778     0:02.9
# Halting: target number of samples (18) reached.
# Done
