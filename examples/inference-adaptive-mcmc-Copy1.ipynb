# %% [markdown]
# # Inference: Adaptive MCMC
#
# This example shows you how to perform Bayesian inference on a time series, using an adaptive MCMC method.

# %%
from __future__ import print_function
import pints
import pints.toy as toy
import numpy as np
import matplotlib.pyplot as pl

# Load a forward model
model = toy.LogisticModel()

# Create some toy data
real_parameters = [0.015, 500]
times = np.linspace(0, 1000, 100)
org_values = model.simulate(real_parameters, times)

# Add noise
noise = 50
values = org_values + np.random.normal(0, noise, org_values.shape)
real_parameters = np.array(real_parameters + [noise])

# Get properties of the noise sample
noise_sample_mean = np.mean(values - org_values)
noise_sample_std = np.std(values - org_values)

# Create an object with links to the model and time series
problem = pints.SingleSeriesProblem(model, times, values)

# Create a log-likelihood function (adds an extra parameter!)
log_likelihood = pints.UnknownNoiseLogLikelihood(problem)

# Create a uniform prior over both the parameters and the new noise variable
prior = pints.UniformPrior(
    [0.01, 400, noise*0.1],
    [0.02, 600, noise*100]
    )

# Create a Bayesian log-likelihood (prior * likelihood)
log_likelihood = pints.BayesianLogLikelihood(prior, log_likelihood)

# Run a simple adaptive mcmc routine
x0 = real_parameters * 1.2
chain = pints.adaptive_covariance_mcmc(log_likelihood, x0)
# Out:
# Iteration 0 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 1.0
# Iteration 50 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0392156862745
# Iteration 100 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.049504950495
# Iteration 150 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.046357615894
# Iteration 200 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0398009950249
# Iteration 250 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0358565737052
# Iteration 300 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0332225913621
# Iteration 350 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.039886039886
# Iteration 400 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0374064837905
# Iteration 450 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0332594235033
# Iteration 500 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0319361277445
# Iteration 550 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0290381125227
# Iteration 600 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0299500831947
# Iteration 650 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0276497695853
# Iteration 700 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0271041369472
# Iteration 750 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0279627163782
# Iteration 800 of 6000
#   In burn-in: True
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.182288876986
# Iteration 5650 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.183330384003
# Iteration 5700 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.184353622172
# Iteration 5750 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.185011302382
# Iteration 5800 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.185140493018
# Iteration 5850 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.185951119467
# Iteration 5900 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.185900694797
# Iteration 5950 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.185851117459

# %%
# Plot output
pl.figure(figsize=(14, 9))
for i, real in enumerate(real_parameters):
    
    # Add subplot
    pl.subplot(len(real_parameters), 1, 1+i)
    pl.xlabel('Parameter ' + str(i + 1))
    
    # Show true value
    pl.axvline(real)
    
    # Show histogram of chain
    pl.hist(chain[:,i], label='p' + str(i + 1), bins=40, color='green',
        alpha=0.5)
    
    # Center plot around mean of chain
    mu = np.mean(chain[:,i])
    sigma = np.std(chain[:,i])
    pl.xlim(mu - 3 * sigma, mu + 3 * sigma)

pl.show()

# %% [markdown]
# ## Trace plot

# %%
#TODO: Redo this example, but show the burn-in too!

pl.figure(figsize=(14, 9))
nparam = len(real_parameters)
for i, real in enumerate(real_parameters):
    
    # Add histogram subplot
    pl.subplot(nparam, 2, 1 + 2 * i)
    pl.xlabel('Parameter ' + str(i + 1))
    pl.ylabel('Frequency')
    pl.axvline(real)
    pl.hist(chain[:,i], label='p' + str(i + 1), bins=40, color='green',
        alpha=0.5)

    # Add trace subplot
    pl.subplot(nparam, 2, 2 + 2 * i)
    pl.xlabel('Iteration (post burn-in)')
    pl.ylabel('Parameter ' + str(i + 1))
    pl.axhline(real)
    pl.plot(chain[:,i], color='green')

pl.tight_layout()
pl.show()

# %%
#TODO: Repeat this, but with KDE (kernel density estimator) plot on the left

# %% [markdown]
# ## Pairwise scatterplot

# %%
# Triangle plot!

# %% [markdown]
# ## Autocorrelation plot

# %%
pl.figure()
print(len(chain[:,0]))
pl.acorr(chain[:,0], maxlags=50)
pl.xlim(0,None)
pl.show()
# Out:
# 375

# %% [markdown]
# ## Fitting result

# %%
pl.figure()
pl.plot(times, values)
pl.show()

# %%
# Evaluate the model for all inferred parameters
new_values = []
for params in chain:
    new_values.append(problem.evaluate(params[:2]))
new_values = np.array(new_values)
mean_values = np.mean(new_values, axis=0)

# Plot them
pl.figure(figsize=(15, 5))
for v in new_values:
    pl.plot(times, v, color='yellow', alpha=0.1)
pl.plot(times, mean_values, label='mean inferred')
pl.plot(times, values, label='original data')
pl.legend()
pl.show()
